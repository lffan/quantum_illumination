# %% [markdown]
# ## Quantum Illumination Experiment 3
#
# __Error probabilities with respect to average photon numbers.__
#
# - Author: L. Fan
# - Created Date: 2017-09-19
# - The Second Latest Modified: 2017-11-16
# - The Latest Modified: 2017-11-19

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# configuration
from IPython.display import set_matplotlib_formats
plt.style.use(['seaborn-whitegrid'])
set_matplotlib_formats('pdf', 'png')
np.set_printoptions(threshold='nan', precision=6, suppress=True)
# %matplotlib inline

# %%
df1 = pd.read_csv('../output/data/basic_attributes.csv', comment='#')
names = ('TMSS', 'PS', 'PA', 'PAS', 'PSA', 'PCS')

# %%
df1.head()
# Out:
#   State  lambda   Exact_N    Aver_N  VN_Entropy      A_aver_N      B_aver_N  \
# 0  TMSS   0.001  0.000002  0.000002    0.000015  9.999990e-07  9.999990e-07
# 1  TMSS   0.010  0.000200  0.000200    0.001021  1.000100e-04  1.000100e-04
# 2  TMSS   0.019  0.000722  0.000722    0.003224  3.611304e-04  3.611304e-04
# 3  TMSS   0.028  0.001569  0.001569    0.006395  7.846151e-04  7.846151e-04
# 4  TMSS   0.037  0.002742  0.002742    0.010409  1.370877e-03  1.370877e-03
#
#    ra  rb
# 0 NaN NaN
# 1 NaN NaN
# 2 NaN NaN
# 3 NaN NaN
# 4 NaN NaN

# %%
df1[df1['State'] == 'PCS'].head()
# Out:
#     State  lambda  Exact_N    Aver_N  VN_Entropy  A_aver_N  B_aver_N   ra   rb
# 505   PCS   0.001      NaN  1.999953    0.000570  0.999976  0.999976  0.4  0.4
# 506   PCS   0.009      NaN  1.996207    0.027356  0.998104  0.998104  0.4  0.4
# 507   PCS   0.017      NaN  1.986688    0.077388  0.993344  0.993344  0.4  0.4
# 508   PCS   0.025      NaN  1.971952    0.139719  0.985976  0.985976  0.4  0.4
# 509   PCS   0.033      NaN  1.952818    0.207527  0.976409  0.976409  0.4  0.4

# %%
for name in ('PS', 'PSA'):
    temp_df = df1[df1['State'] == name]
    plt.plot(temp_df['Aver_N'] / 2, temp_df['VN_Entropy'], 
             lw=2, label=name)
for name in ('PA', 'PAS', 'PCS'):
    temp_df = df1[df1['State'] == name]
    plt.plot((temp_df['Aver_N'] - 2) / 2, temp_df['VN_Entropy'], 
             lw=2, label=name)
# plt.xlim(0, 2)
# plt.ylim(0.43, 0.5)
plt.legend(loc=0, fontsize=14)
plt.xlabel("Average Photon Number")
plt.ylabel("Entropy")
plt.title("Von Neumann Entropy")
plt.show()

# %%
for name in names:
    temp_df = df1[df1['State'] == name]
    plt.plot(temp_df['Aver_N'] / 2, temp_df['VN_Entropy'], 
             lw=2, label=name)
# plt.xlim(0, 1)
# plt.ylim(0, 0.5)
plt.legend(loc=0, fontsize=14)
plt.xlabel("Average Photon Number")
plt.ylabel("Entropy")
plt.title("Von Neumann Entropy")
plt.show()

# %%
for name in ('TMSS', 'PS', 'PA', 'PAS'):
    temp_df = df1[df1['State'] == name]
    plt.plot(temp_df['Aver_N'], 
             (temp_df['Exact_N'] - temp_df['Aver_N']), 
             lw=2, label=name)
# plt.xlim(0, 2)
# plt.ylim(0.43, 0.5)
plt.legend(loc=0, fontsize=14)
plt.xlabel("Average Photon Number")
plt.ylabel("Exact Photon Number")
plt.title("Exact Photon Number")
plt.show()

# %%
for name in names:
    temp_df = df1[df1['State'] == name]
    plt.plot(temp_df['lambda'], temp_df['VN_Entropy'], 
             lw=2, label=name)
# plt.xlim(0, 2)
# plt.ylim(0.43, 0.5)
plt.legend(loc=0, fontsize=14)
plt.xlabel("$\lambda$")
plt.ylabel("Entropy")
plt.title("Von Neumann Entropy")
plt.show()

# %%
for name in names:
    temp_df = df1[df1['State'] == name]
    plt.plot(temp_df['lambda'], temp_df['Aver_N'], 
             lw=2, label=name)
# plt.xlim(0, 2)
# plt.ylim(0.43, 0.5)
plt.legend(loc=0, fontsize=14)
plt.xlabel("$\lambda$")
plt.ylabel("Photon Number")
plt.title("Photon Number")
plt.show()

# %%
np.tanh(1.0)
# Out:
# 0.76159415595576485

# %%
l = np.tanh(0.1)

# %%
n = l**2 / (1 - l**2)

# %%
n
# Out:
# 0.010033377809537924

# %%
l = np.sqrt(0.01/1.01)

# %%
l
# Out:
# 0.099503719020998915

# %%
np.arctanh(l)
# Out:
# 0.099834078899207562
