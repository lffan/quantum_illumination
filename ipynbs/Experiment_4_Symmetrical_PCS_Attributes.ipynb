# %% [markdown]
# ## Quantum Illumination Experiement 4
#
# __Basic attributes of symmetrical PCS states.__
#
# - Author: L. Fan
# - Created Date: 2018-03-31
# - The Latest Modified: 2018-03-31
#
# Log:
# - 03-31 created

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# import seaborn as sns

# %%
# configuration
# from IPython.display import set_matplotlib_formats
# set_matplotlib_formats('pdf', 'png')
# np.set_printoptions(threshold='nan', precision=6, suppress=True)
plt.style.use(['seaborn-whitegrid', '14pt'])
# %matplotlib inline

# %%
filename = 'expr_4_pcs_nmax_32_201x201_04-12.csv'
df = pd.read_csv('../output/data/expr_4/' + filename, comment='#')

# %%
df.head()
# Out:
#    nmax State       sqz        lambda  Exact_N        Aver_N    VN_Entropy  \
# 0    32   PCS  0.000001  1.000000e-06      NaN  8.000000e-12  1.089790e-10
# 1    32   PCS  0.000001  1.000000e-06      NaN  1.996805e+00  1.188318e-02
# 2    32   PCS  0.000001  1.000000e-06      NaN  1.999800e+00  1.021121e-03
# 3    32   PCS  0.000001  1.000000e-06      NaN  1.999961e+00  2.338144e-04
# 4    32   PCS  0.000001  1.000000e-06      NaN  1.999988e+00  8.120274e-05
#
#        A_aver_N      B_aver_N     ra     rb
# 0  4.000000e-12  4.000000e-12  0.000  0.000
# 1  9.984026e-01  9.984026e-01  0.005  0.005
# 2  9.999000e-01  9.999000e-01  0.010  0.010
# 3  9.999803e-01  9.999803e-01  0.015  0.015
# 4  9.999938e-01  9.999938e-01  0.020  0.020

# %%
df.tail()
# Out:
#        nmax State       sqz    lambda  Exact_N     Aver_N  VN_Entropy  \
# 40396    32   PCS  1.000001  0.761595      NaN  10.939489    2.350064
# 40397    32   PCS  1.000001  0.761595      NaN  10.958809    2.373040
# 40398    32   PCS  1.000001  0.761595      NaN  10.978723    2.397270
# 40399    32   PCS  1.000001  0.761595      NaN  10.999268    2.422833
# 40400    32   PCS  1.000001  0.761595      NaN  11.020482    2.449817
#
#        A_aver_N  B_aver_N     ra     rb
# 40396  5.469745  5.469745  0.980  0.980
# 40397  5.479404  5.479404  0.985  0.985
# 40398  5.489362  5.489362  0.990  0.990
# 40399  5.499634  5.499634  0.995  0.995
# 40400  5.510241  5.510241  1.000  1.000

# %%
sqz = df['sqz'].unique()
sqz[1] - sqz[0]
# Out:
# 0.0049999999999999992

# %%
temp = df.loc[(df['sqz'] >= 0.309) & (df['sqz'] <= 0.311)]
plt.plot(temp['ra'], temp['VN_Entropy'])
plt.show()

# %%
temp = df.loc[(df['sqz'] >= 0.314) & (df['sqz'] <= 0.316)]
plt.plot(temp['ra'], temp['VN_Entropy'])
plt.show()

# %%
temp = df.loc[(df['sqz'] >= 0.319) & (df['sqz'] <= 0.324)]
plt.plot(temp['ra'], temp['VN_Entropy'])
plt.show()

# %%
vn = df['VN_Entropy'].values.reshape(201, 201)
plt.imshow(vn, cmap='RdBu_r', interpolation='BiCubic', 
           origin='lower', extent=[0, 1, 0, 1.0])
plt.colorbar()
plt.show()

# %%
from matplotlib import cm

vn = df['VN_Entropy'].values.reshape(201, 201)
rs = df['ra'].values.reshape(201, 201)
ss = df['sqz'].values.reshape(201, 201)
nb = df['B_aver_N'].values.reshape(201, 201)

fig = plt.contour(rs, ss, vn, 
                  levels=np.arange(0.02, 2.42, 0.2),
                  cmap='gnuplot')
plt.clabel(fig, inline=1, fontsize=12)
plt.axes().set_aspect('equal')
plt.title('PCS - entropy of entanglement')
plt.xlabel('$r$')
plt.ylabel('$s$')
plt.show()

# %%
fig = plt.contour(rs, ss, nb, 
                  levels=np.arange(0.02, 5.42, 0.2),
                  cmap='gnuplot')
plt.clabel(fig, inline=1, fontsize=12)
plt.axes().set_aspect('equal')
plt.title('PCS - entropy of entanglement')
plt.xlabel('$r$')
plt.ylabel('$s$')
plt.show()

# %%
plt.scatter(df['Aver_N'], df['VN_Entropy'], s=0.05, alpha=0.5)
plt.xlabel('Photon Number of Mode B')
plt.ylabel('Entropy of Entanglement')
plt.show()

# %%
plt.scatter(df['B_aver_N'], df['VN_Entropy'], s=0.05, alpha=0.5)
plt.xlabel('Photon Number of Mode B')
plt.ylabel('Entropy of Entanglement')
plt.show()
