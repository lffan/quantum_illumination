# %% [markdown]
# ## Quantum Illumination Experiment 3
#
# __Error probabilities with respect to average photon numbers.__
#
# - Author: L. Fan
# - Created Date: 2017-09-19
# - The Second Latest Modified: 2017-11-16
# - The Latest Modified: 2017-11-19

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# configuration
from IPython.display import set_matplotlib_formats
plt.style.use(['seaborn-whitegrid'])
set_matplotlib_formats('pdf', 'png')
np.set_printoptions(threshold='nan', precision=6, suppress=True)
# %matplotlib inline

# %%
df1 = pd.read_csv('../output/data/expr_3_nbar_nth_1.0_g_51_11-26.csv', comment='#')
names = ('TMSS', 'PS', 'PA', 'PAS', 'PSA', 'PCS')
# names = ('TMSS', 'PS', 'PSA')

# %%
df1.

# %%
df1.head()
# Out:
#    Nth     R State  lambda    Aver_N  VN_Entropy  Helstrom_Bound  \
# 0    1  0.01  TMSS    0.00  0.000002    0.000015        0.499966
# 1    1  0.01  TMSS    0.03  0.000512    0.002374        0.499461
# 2    1  0.01  TMSS    0.06  0.001924    0.007644        0.498956
# 3    1  0.01  TMSS    0.09  0.004241    0.015177        0.498452
# 4    1  0.01  TMSS    0.12  0.007470    0.024620        0.497948
#
#    Chernoff_Bound  optimal_s  A_aver_N  B_aver_N  ra  rb
# 0        0.500000        0.5  0.000001  0.000001 NaN NaN
# 1        0.499999        0.5  0.000256  0.000256 NaN NaN
# 2        0.499998        0.5  0.000962  0.000962 NaN NaN
# 3        0.499995        0.5  0.002120  0.002120 NaN NaN
# 4        0.499991        0.5  0.003735  0.003735 NaN NaN

# %%
for name in names:
    temp_df = df1[df1['State'] == name]
    plt.plot(temp_df['Aver_N'], temp_df['Helstrom_Bound'], 
             lw=2, label=name)
# plt.xlim(0, 2)
# plt.ylim(0.43, 0.5)
plt.legend(loc=3, fontsize=14)
plt.xlabel("Average Photon Number")
plt.ylabel("Helstrom Bound")
plt.title("Helstrom Bound")
plt.show()

# %%
for name in names:
    temp_df = df1[df1['State'] == name]
    plt.plot(temp_df['Aver_N'], temp_df['Chernoff_Bound'], 
             lw=2, label=name)
# plt.xlim(0, 2)
# plt.ylim(0.494, 0.5)
plt.legend(fontsize=14)
plt.xlabel("Average Photon Number", fontsize=14)
plt.ylabel("Chernoff Bound", fontsize=14)
plt.title("Chernoff Bound", fontsize=14)

# %%
for name in names:
    temp_df = df1[df1['State'] == name]
    plt.plot(temp_df['Aver_N'], temp_df['VN_Entropy'], 
             lw=2, label=name)
# plt.xlim(0, 2)
# plt.ylim(0.494, 0.5)
plt.legend(fontsize=14)
plt.xlabel("Average Photon Number", fontsize=14)
plt.ylabel("Entropy", fontsize=14)
plt.title("Entropy", fontsize=14)
