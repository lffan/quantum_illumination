# %% [markdown]
# ## Quantum Illumination Experiment 3
#
# __Error probabilities with respect to average photon numbers.__
#
# - Author: L. Fan
# - Created Date: 2017-09-19
# - The Second Latest Modified: 2017-11-16
# - The Latest Modified: 2017-11-19

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# configuration
from IPython.display import set_matplotlib_formats
plt.style.use(['seaborn-whitegrid', '14pt'])
set_matplotlib_formats('pdf', 'png')
np.set_printoptions(threshold='nan', precision=6, suppress=True)
# %matplotlib inline

# %%
df1 = pd.read_csv('../output/expr_3_nbar_nth_0.1_g_11_11-26.csv', comment='#')
# names = ('TMSS', 'PS', 'PA', 'PAS', 'PSA', 'PCS')
names = ('TMSS', 'PS', 'PSA')

# %%
df1.head()
# Out:
#    Nth     R State  lambda    Aver_N  VN_Entropy  Helstrom_Bound  \
# 0  0.1  0.01  TMSS   0.001  0.000002    0.000015        0.499953
# 1  0.1  0.01  TMSS   0.081  0.013209    0.039780        0.496160
# 2  0.1  0.01  TMSS   0.161  0.053222    0.123464        0.492332
# 3  0.1  0.01  TMSS   0.241  0.123325    0.235322        0.488425
# 4  0.1  0.01  TMSS   0.321  0.229756    0.369820        0.484385
#
#    Chernoff_Bound  optimal_s      A_aver_N      B_aver_N  ra  rb
# 0        0.500000   0.498281  9.999990e-07  9.999990e-07 NaN NaN
# 1        0.499971   0.500215  6.604331e-03  6.604331e-03 NaN NaN
# 2        0.499890   0.500273  2.661078e-02  2.661078e-02 NaN NaN
# 3        0.499756   0.500332  6.166241e-02  6.166241e-02 NaN NaN
# 4        0.499565   0.500391  1.148782e-01  1.148782e-01 NaN NaN

# %%
for name in names:
    temp_df = df1[df1['State'] == name]
    plt.plot(temp_df['Aver_N'], temp_df['Helstrom_Bound'], 
             lw=2, label=name)
# plt.xlim(0, 2)
# plt.ylim(0.43, 0.5)
plt.legend(loc=3, fontsize=14)
plt.xlabel("Average Photon Number")
plt.ylabel("Helstrom Bound")
plt.title("Helstrom Bound")
plt.show()

# %%
for name in names:
    temp_df = df1[df1['State'] == name]
    plt.plot(temp_df['Aver_N'], temp_df['Chernoff_Bound'], 
             lw=2, label=name)
# plt.xlim(0, 2)
# plt.ylim(0.494, 0.5)
plt.legend(fontsize=14)
plt.xlabel("Average Photon Number", fontsize=14)
plt.ylabel("Chernoff Bound", fontsize=14)
plt.title("Chernoff Bound", fontsize=14)

# %%
for name in names:
    temp_df = df1[df1['State'] == name]
    plt.plot(temp_df['Aver_N'], temp_df['VN_Entropy'], 
             lw=2, label=name)
# plt.xlim(0, 2)
# plt.ylim(0.494, 0.5)
plt.legend(fontsize=14)
plt.xlabel("Average Photon Number", fontsize=14)
plt.ylabel("Entropy", fontsize=14)
plt.title("Entropy", fontsize=14)
